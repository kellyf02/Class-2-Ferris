# %% [markdown]
# <a href="https://colab.research.google.com/github/kellyf02/Class-2-Ferris/blob/main/Week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## PANDAS
#
# - Pandas is a data analysis package is used to handle dataframes, much like Excel (but better!)
#
# - The two most important classes are:
#
#     - `Series` (like a 1D array)
#     - `DataFrame`: 2D datasets with rows (observations) and columns (variables).
#
# - The pandas module is usually imported with `pd`, like how numpy is imported `np`.

# %%
# !pip install pandas
import numpy as np
import pandas as pd

# %% [markdown]
# ## Pandas Series
# - One-dimensional array
# - Series can be like an array, with a standard integer index starting at 0, or like a dictionary, with a defined index.

# %%
import pandas as pd
data_list = [10,15,35,64,100]

my_series = pd.Series(data_list) # array-like pandas series, index created automatically
my_series1 = pd.Series([100,101,102,103,104]) #you can put the values in directly without creating a list called data.
my_series2 = pd.Series(data_list, index=['a', 'b', 'c', 'd', 'e'])  # index specified

print(my_series, '\n', my_series1, '\n', my_series2)
# Out:
# 0     10
# 1     15
# 2     35
# 3     64
# 4    100
# dtype: int64
#  0    100
# 1    101
# 2    102
# 3    103
# 4    104
# dtype: int64
#  a     10
# b     15
# c     35
# d     64
# e    100
# dtype: int64

# %%
my_series2['a']
# Out:
# 10

# %% [markdown]
# # Plotting a Series
#
# - We can plot a series by invoking the `plot()` method on an instance of a `Series` object.
#
# - The y-axis will plot the data values while the x-axis will automatically x-axis will be labeled with the series index.

# %%
# %matplotlib inline
# my_series.plot()
# my_series1.plot()
my_series2.plot()
# Out:
# <Axes: >

# %% [markdown]
# # Creating a Series from a `dict`

# %%
d = {'a' : 0., 'b' : 1., 'c' : 2.}
my_series = pd.Series(d)
my_series
# Out:
# a    0.0
# b    1.0
# c    2.0
# dtype: float64

# %%
## Exercise: Create 5 random English Test scores out of 100, with 5 names of students in the index.

import numpy as np
english = pd.Series(np.random.randint(0,100,5), ['Mark', 'Barbara', 'David', 'Greg', 'Lauren'])
english
# Out:
# Mark       15
# Barbara    34
# David      23
# Greg       39
# Lauren     93
# dtype: int64

# %%
## Exercise: Create 6 random history Test scores out of 100, with 6 names of students in the index. All students must pass the class.

import numpy as np
history = pd.Series(np.random.randint(67,100,6), ['Mark', 'Barbara', 'David', 'Greg', 'Lauren', 'Tejas'])
history
# Out:
# Mark       70
# Barbara    74
# David      82
# Greg       92
# Lauren     77
# Tejas      91
# dtype: int64

# %% [markdown]
# # Indexing/Slicing a Series with `[]` or . notation
#
# - We can also specify a range with `my_series[['b', 'c']]`

# %%
#Notice the different ways that the parts of the series are specified.

print('First way:',my_series['b'],'\n', 'Second way:',my_series.b, '\n\n', 'Range:\n',my_series[['b', 'c']])
# Out:
# First way: 1.0
#  Second way: 1.0
#
#  Range:
#  b    1.0
# c    2.0
# dtype: float64

# %% [markdown]
# ## Series Functions

# %%
#These are just a variety of examples of operations on series.

starter = {'a' : 5., 'b' : 15., 'c' : 25.}

start = pd.Series(starter)
print('Print the entire array start: \n', start)

start_ten=10*start
print('Mulitiply start by 10:\n', start_ten)

start_ten_2=start.multiply(10)
print('Mulitiply by 10 using the function:\n', start_ten_2)

start_add=start+start_ten
print('Adding directly:\n', start_add)

start_add2=pd.Series.add(start,start_ten) # Numpy used us np.add
print('Adding with a function:\n', start_add2)

sum_start=pd.Series.sum(start)
print('sum all of a:\n', sum_start)

f=start**2  #This squares the value.
print('square of start:\n', f)
# Out:
# Print the entire array start:
#  a     5.0
# b    15.0
# c    25.0
# dtype: float64
# Mulitiply start by 10:
#  a     50.0
# b    150.0
# c    250.0
# dtype: float64
# Mulitiply by 10 using the function:
#  a     50.0
# b    150.0
# c    250.0
# dtype: float64
# Adding directly:
#  a     55.0
# b    165.0
# c    275.0
# dtype: float64
# Adding with a function:
#  a     55.0
# b    165.0
# c    275.0
# dtype: float64
# sum all of a:
#  45.0
# square of start:
#  a     25.0
# b    225.0
# c    625.0
# dtype: float64

# %% [markdown]
# ## Class Exercise
#
# Add 2 pandas series together: First manually, second with a function

# %%
## Example:

x = pd.Series({'a' : 0., 'b' : 1., 'c' : 2.})
y = pd.Series({'a' : 3., 'b' : 4., 'c' : 5.})
z = x+y
print('Add 2 series together:\n', z)

# now add x and y using functions
# Out:
# Add 2 series together:
#  a    3.0
# b    5.0
# c    7.0
# dtype: float64

# %% [markdown]
# ## Time Series
# - Time series models link specific times with rows.

# %%
dates = pd.date_range('1/1/2000', periods=5)
dates
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05'],
#               dtype='datetime64[ns]', freq='D')

# %%
time_series = pd.Series(data_list, index=dates)
time_series
# Out:
# 2000-01-01     10
# 2000-01-02     15
# 2000-01-03     35
# 2000-01-04     64
# 2000-01-05    100
# Freq: D, dtype: int64

# %% [markdown]
# ## Plot Time Series
# - With a data and a value, the plot command can be used to provide quick visibility in the form of a line graph.

# %%
ax = time_series.plot()

# %% [markdown]
# ## DataFrames
#
# - The `pandas` module provides a powerful data-structure called a data frame.
#
# - It is similar to: a relational database table, an Excel spreadsheet, or a dataframe in R.
#
# - A data frame has multiple columns, each of which can hold a *different* type of value.
#
# - It has an index label for every row, just like Series.
# - Data frames can be read and written to/from: database queries, database tables, CSV files, json files

# %% [markdown]
# ## Example: Creating a DataFrame from Multiple Series
# - Pandas codes missing values as `NaN` rather than `None`

# %%
d = {
        'x' :
            pd.Series([1, 12, 18, 21], index=['a', 'b', 'c','d']),
        'y' :
            pd.Series([4., 6., 7.], index=['a', 'c', 'd']),
        'z' :
            pd.Series([0.2, 0.3, 0.4], index=[ 'b', 'c', 'd'])
}

df = pd.DataFrame(d)
print (df)
type(d)
# Out:
#     x    y    z
# a   1  4.0  NaN
# b  12  NaN  0.2
# c  18  6.0  0.3
# d  21  7.0  0.4
# dict

# %%
## Data types of each column
print(df.dtypes)
# Out:
# x      int64
# y    float64
# z    float64
# dtype: object

# %% [markdown]
# # Plotting DataFrames
#
#
# - The column names are used to label each series, and the row names (index) is used to label the x-axis.

# %%
ax = df.plot()

# %%
nulls=df.isnull()
print(nulls, "\n", type(nulls))

nullsum=nulls.sum()

print("\nNull sum for each column \n", nullsum, "\n", type(nullsum))

print("\nWe can slice these results to get the answer for x \n", nullsum.x)
type(nullsum.x)
# Out:
#        x      y      z
# a  False  False   True
# b  False   True  False
# c  False  False  False
# d  False  False  False
#  <class 'pandas.core.frame.DataFrame'>
#
# Null sum for each column
#  x    0
# y    1
# z    1
# dtype: int64
#  <class 'pandas.core.series.Series'>
#
# We can slice these results to get the answer for x
#  0
# numpy.int64

# %%
## To make a copy of a dataframe df, use the `copy` method: `df2= df.copy()`
df2= df.copy()
print(df, '\n', df2)
# Out:
#     x    y    z
# a   1  4.0  NaN
# b  12  NaN  0.2
# c  18  6.0  0.3
# d  21  7.0  0.4
#      x    y    z
# a   1  4.0  NaN
# b  12  NaN  0.2
# c  18  6.0  0.3
# d  21  7.0  0.4

# %%
df2=df ** 2 #This squares all values.
print(df2)
# Out:
#      x     y     z
# a    1  16.0   NaN
# b  144   NaN  0.04
# c  324  36.0  0.09
# d  441  49.0  0.16

# %% [markdown]
# ## Summary statistics
# -  `describe` will give us descriptive statistics, like the count, sum, mean, median, confidence intervals, or standard deviation.

# %%
dfstats=df.describe()
dfstats
# Out:
#                 a           b           c           d
# count   10.000000   10.000000   10.000000   10.000000
# mean    13.688537    4.304871   12.166588  -17.834578
# std    113.439951   85.223975   57.196703  119.661634
# min   -138.235397 -114.630121  -78.345353 -211.817353
# 25%    -79.647868  -64.976011   -2.497449  -91.094153
# 50%     22.491237    3.298144   15.629151    7.519726
# 75%     60.764730   77.664702   34.296683   47.198213
# max    240.848916  130.546769  123.146851  190.509272

# %%
xmean = dfstats['a']['mean'] # mean of column x was a
ystd = dfstats['y']['std'] #standard deviation of column y

print('The average of column X in DataFrame df is:',xmean,'\n\n The std dev of column y in DataFrame df is:',ystd)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'y'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-a5a6747baaed> in <cell line: 0>()
#       1 xmean = dfstats['a']['mean'] # mean of column x was a
# ----> 2 ystd = dfstats['y']['std'] #standard deviation of column y
#       3
#       4 print('The average of column X in DataFrame df is:',xmean,'\n\n The std dev of column y in DataFrame df is:',ystd)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'y'

# %% [markdown]
# # Accessing the Row and Column Labels
#
# - The row labels (index) can be accessed through `df.index`.
# - The column labels can be accessed through `df.columns`.

# %%
print(df.index)

df.columns
# Out:
# RangeIndex(start=0, stop=10, step=1)
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %% [markdown]
# ## Class Exercise: Create a dataframe out of a series of dictionaries

# %%
# Index is 4 items at grocery store,  column is price, country inventory

products = {'Price' :
            pd.Series([5., 3.49, 6.99, 8.79,2.99], index=['Apple','Bread', 'Cauliflower', 'Peanuts', 'Beets']),
        'Origin Country' :
            pd.Series(['USA', 'Canada', 'Mexico', 'Guatemala','Honduras'], index=['Apple','Bread', 'Cauliflower', 'Peanuts', 'Beets']),
        'Inventory' :
            pd.Series(['High', 'Low', 'Medium','Low','High'], index=[ 'Apple','Bread', 'Cauliflower', 'Peanuts', 'Beets'])
}

produce = pd.DataFrame(products)
produce
# Out:
#              Price Origin Country Inventory
# Apple         5.00            USA      High
# Bread         3.49         Canada       Low
# Cauliflower   6.99         Mexico    Medium
# Peanuts       8.79      Guatemala       Low
# Beets         2.99       Honduras      High

# %% [markdown]
# ## Loading Files with Pandas
# - We used Pandas in an earlier notebook to load the iris data file.
# - Whenver you have a dataset with a variety of fields of various types, loading it into Pandas is a good strategy.
# - You can load data from Azure, from a local file, or from a url.

# %%
# !wget https://raw.githubusercontent.com/JyothsnaGH/PythonforFinance/main/files/iris.csv
# Out:
# --2025-02-06 22:30:04--  https://raw.githubusercontent.com/JyothsnaGH/PythonforFinance/main/files/iris.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3868 (3.8K) [text/plain]
# Saving to: ‘iris.csv’
#
# iris.csv            100%[===================>]   3.78K  --.-KB/s    in 0s
#
# 2025-02-06 22:30:04 (51.4 MB/s) - ‘iris.csv’ saved [3868/3868]

# %%
# Pulling from a local file
iris_df = pd.read_csv('iris.csv')
iris_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# Pulling from a url.  Notice that this is the raw version of the file.
iris_df_alt = pd.read_csv("https://raw.githubusercontent.com/JyothsnaGH/PythonforFinance/main/files/iris.csv")
iris_df_alt.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ##  Large Dataframes - Head and Tail
#
# - Many times you just want a sampling of the available data
# - The `head()` command shows you the first 5 rows of a data frame by default, while the `tail()` command shows you the last 5 rows of a data frame.

# %%
iris_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-d721b3361508> in <cell line: 0>()
# ----> 1 iris_df.head()
#
# NameError: name 'iris_df' is not defined

# %%
iris_df.tail(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-5b34d11e811d> in <cell line: 0>()
# ----> 1 iris_df.tail(10)
#
# NameError: name 'iris_df' is not defined

# %% [markdown]
# ## Class Exercise
# Find the summary statistics of the IRIS dataset.

# %% [markdown]
# ## Indexing DataFrames
# - Simple ways of selecting all rows and columns is (`df[:]`)
# - Rows can be accessed via a key or a integer corresponding to the row number.
# - When we retrieve a single column (multiple columns), the result is a Series (dataFrame).

# %%
print (iris_df.petal_length) #All rows, column 3 (index is 2)

# 4 different methods of Printing Columns 3 and 4 (positions 2 and 3)
print ('\n1: Print Columns 2 and 3 by using the Column Name\n',iris_df[['petal_length', 'petal_width']]) #All rows, columns 3-4
print ('\n\n2: iloc: Print Columns 2 and 3 by using the Column Index\n',iris_df.iloc[:,2:4]) # Same as above using iloc method
print ('\n\n3: loc: Print Columns 2 and 3 by using the Column alt\n',iris_df.loc[:,['petal_length', 'petal_width']]) # Same as above using loc method
print ('\n\n4: loc: Print Columns 2 and 3 by using the Column another alt\n',iris_df.loc[:,'petal_length':'petal_width']) # Same as above using loc method

# %%
iris_df[['petal_length', 'petal_width']]
iris_df.iloc[:,2:4]
iris_df.loc[:,['petal_length', 'petal_width']]
iris_df.loc[:,'petal_length':'petal_width']

# %%
## Additional Practice: Print Selected Columns

# print ('\n\nilocmethod:\n',iris_df.iloc[:,[0,2,3]])
# print ('\nlocmethod:\n',iris_df.loc[:,['sepal_length','petal_length','petal_width']])
# print ('\nilocmethod:\n',iris_df.iloc[:,0:2])
# print ('\nlocmethod:\n',iris_df.loc[:,'sepal_length':'sepal_width'])

# %%
## Selecting rows

print (iris_df[0:3])     #Select rows 1-3
print ('\nSelect rows 1-3:\n',iris_df.iloc[0:3,:])     #Select rows 1-3. df.iloc[0:3,] will also do.
print ('\nSelect rows 1-3 alternative:\n',iris_df.iloc[0:3])       #Select rows 1-3
print ('\nSelect rows 1, 2, and 4:\n',iris_df.iloc[[1,2,4]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b9f28cfeb53e> in <cell line: 0>()
#       1 ## Selecting rows
#       2
# ----> 3 print (iris_df[0:3])     #Select rows 1-3
#       4 print ('\nSelect rows 1-3:\n',iris_df.iloc[0:3,:])     #Select rows 1-3. df.iloc[0:3,] will also do.
#       5 print ('\nSelect rows 1-3 alternative:\n',iris_df.iloc[0:3])       #Select rows 1-3
#
# NameError: name 'iris_df' is not defined

# %% [markdown]
# ## Class Exercise: Remember the produce dataframe you created last class. Now we will index it by column.
#
# Create a dataframe with 10 products as the index (apples, bananas, oranges, etc.) and 4 columns (price, inventory, country, category). Print it.
#
# 1) Print the first 2 columns using 2 methods.
# 2) print the last 2 columns and only first 5 rows.
# 3) Print the last 2 rows and last 2 columns.
# 4) Print rows 3,5,7,8,9 and columns 1, 2, and 4.

# %%
## Class Exercise: Enter your Answer here

import pandas as pd
import numpy as np

# Create the dataframe
products = {
    'Price': pd.Series([2.99, 0.79, 1.49, 3.99, 0.99, 4.99, 2.49, 1.99, 0.59, 1.29],
                      index=['Apples', 'Bananas', 'Oranges', 'Grapes', 'Strawberries', 'Blueberries', 'Raspberries', 'Blackberries', 'Kiwi', 'Mango']),
    'Inventory': pd.Series(['High', 'Medium', 'High', 'Low', 'Medium', 'High', 'Low', 'Medium', 'High', 'Medium'],
                          index=['Apples', 'Bananas', 'Oranges', 'Grapes', 'Strawberries', 'Blueberries', 'Raspberries', 'Blackberries', 'Kiwi', 'Mango']),
    'Country': pd.Series(['USA', 'Ecuador', 'Spain', 'Chile', 'USA', 'Canada', 'Mexico', 'Mexico', 'New Zealand', 'India'],
                        index=['Apples', 'Bananas', 'Oranges', 'Grapes', 'Strawberries', 'Blueberries', 'Raspberries', 'Blackberries', 'Kiwi', 'Mango']),
    'Category': pd.Series(['Fruit', 'Fruit', 'Fruit', 'Fruit', 'Fruit', 'Fruit', 'Fruit', 'Fruit', 'Fruit', 'Fruit'],
                         index=['Apples', 'Bananas', 'Oranges', 'Grapes', 'Strawberries', 'Blueberries', 'Raspberries', 'Blackberries', 'Kiwi', 'Mango'])
}

produce = pd.DataFrame(products)
print(produce)

# 1) Print the first 2 columns using 2 methods
print('\nMethod 1:')
print(produce[['Price', 'Inventory']])  # Using column names
print('\nMethod 2:')
print(produce.iloc[:, 0:2])  # Using column indices

# 2) Print the last 2 columns and only first 5 rows
print('\nLast 2 columns, first 5 rows:')
print(produce.iloc[0:5, 2:])

# 3) Print the last 2 rows and last 2 columns
print('\nLast 2 rows, last 2 columns:')
print(produce.iloc[-2:, -2:])

# 4) Print rows 3,5,7,8,9 and columns 1, 2, and 4
print('\nSpecific rows and columns:')
print(produce.iloc[[2, 4, 6, 7, 8], [0, 1, 3]]) # Remember that Python uses 0-based indexing
# Out:
#               Price Inventory      Country Category
# Apples         2.99      High          USA    Fruit
# Bananas        0.79    Medium      Ecuador    Fruit
# Oranges        1.49      High        Spain    Fruit
# Grapes         3.99       Low        Chile    Fruit
# Strawberries   0.99    Medium          USA    Fruit
# Blueberries    4.99      High       Canada    Fruit
# Raspberries    2.49       Low       Mexico    Fruit
# Blackberries   1.99    Medium       Mexico    Fruit
# Kiwi           0.59      High  New Zealand    Fruit
# Mango          1.29    Medium        India    Fruit
#
# Method 1:
#               Price Inventory
# Apples         2.99      High
# Bananas        0.79    Medium
# Oranges        1.49      High
# Grapes         3.99       Low
# Strawberries   0.99    Medium
# Blueberries    4.99      High
# Raspberries    2.49       Low
# Blackberries   1.99    Medium
# Kiwi           0.59      High
# Mango          1.29    Medium
#
# Method 2:
#               Price Inventory
# Apples         2.99      High
# Bananas        0.79    Medium
# Oranges        1.49      High
# Grapes         3.99       Low
# Strawberries   0.99    Medium
# Blueberries    4.99      High
# Raspberries    2.49       Low
# Blackberries   1.99    Medium
# Kiwi           0.59      High
# Mango          1.29    Medium
#
# Last 2 columns, first 5 rows:
#               Country Category
# Apples            USA    Fruit
# Bananas       Ecuador    Fruit
# Oranges         Spain    Fruit
# Grapes          Chile    Fruit
# Strawberries      USA    Fruit
#
# Last 2 rows, last 2 columns:
#            Country Category
# Kiwi   New Zealand    Fruit
# Mango        India    Fruit
#
# Specific rows and columns:
#               Price Inventory Category
# Oranges        1.49      High    Fruit
# Strawberries   0.99    Medium    Fruit
# Raspberries    2.49       Low    Fruit
# Blackberries   1.99    Medium    Fruit
# Kiwi           0.59      High    Fruit

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame((np.random.randn(10, 4)*100),  columns=['a', 'b', 'c', 'd'] )
print (df)
df2 = pd.DataFrame((25+np.random.randn(10, 4)*25),  columns=['e', 'f', 'g', 'h'] )
print ('\n\nThe second dataframe is:\n\n',df2)
# Out:
#             a           b           c           d
# 0 -106.430471   90.881054   13.069950   23.149396
# 1   53.738540  -41.080465   11.879938 -211.817353
# 2  -96.347723  -23.608183  -68.466945  -93.959361
# 3   63.106793 -114.630121   47.016237   69.473786
# 4   11.724826   30.204470   -7.289911  -82.498530
# 5  240.848916  -72.941194  123.146851  190.509272
# 6 -138.235397  130.546769   18.188352   -8.109944
# 7  104.770537   49.374641  -78.345353 -159.333551
# 8  -29.548304   87.094723   37.359985   47.276173
# 9   33.257647  -92.792983   25.106776   46.964333
#
#
# The second dataframe is:
#
#             e          f          g          h
# 0   4.112407  51.344909  12.818224   7.571010
# 1 -20.235359  55.486828   5.818515  52.268135
# 2 -11.719167 -16.258112  29.005079  47.441353
# 3  32.141968  24.697808   0.874261 -31.797176
# 4  23.285734  15.590085  18.185513  32.896418
# 5  14.217338  57.710458   0.871919  26.131426
# 6  42.652661  38.795740  42.115725 -13.255491
# 7   4.668202  16.254984  -6.550162   9.916632
# 8  30.682276  -6.348037  74.003832  36.285178
# 9   5.719307  92.510474  64.067051  28.701084

# %% [markdown]
# ## Dropping Columns from Dataframes

# %%
print (df2)
df2.drop(['e','f'], inplace=True, axis=1) # This line is causing the error. Commenting out to see if there are other errors
print ('\n df2 after potentially dropping e and f:\n',df2)
# Out:
#            a          b          c          d
# 0  21.127944  14.052390  17.735565  25.198823
# 1  16.573375   8.342991  23.728891  23.323299
# 2  11.206399  21.060595  23.968537  22.660950
# 3  22.308625  24.872349  20.606320  16.688822
# 4  15.862087  23.420373  19.995945  19.189474
# 5  20.902073  19.503763  12.778173  17.326116
# 6  16.655070  14.464856  21.076961  11.099739
# 7  31.881189  17.901275  16.598684  24.132576
# 8  13.739202   8.017390  22.414591  17.773509
# 9  28.487225  16.679654  14.259730  19.046314
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-916cd0d3a5f8> in <cell line: 0>()
#       1 print (df2)
# ----> 2 df2.drop(['e','f'], inplace=True, axis=1) # This line is causing the error. Commenting out to see if there are other errors
#       3 print ('\n df2 after potentially dropping e and f:\n',df2)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4828                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4829             else:
# -> 4830                 new_axis = axis.drop(labels, errors=errors)
#    4831             indexer = axis.get_indexer(new_axis)
#    4832
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    7068         if mask.any():
#    7069             if errors != "ignore":
# -> 7070                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071             indexer = indexer[~mask]
#    7072         return self.delete(indexer)
#
# KeyError: "['e', 'f'] not found in axis"

# %%
print (df2)
# df2.drop(['e','f'], inplace=True, axis=1) # This line is causing the error. Commenting out to see if there are other errors
print ('\n df2 after potentially dropping e and f:\n',df2)
# Out:
#            g          h
# 0  12.818224   7.571010
# 1   5.818515  52.268135
# 2  29.005079  47.441353
# 3   0.874261 -31.797176
# 4  18.185513  32.896418
# 5   0.871919  26.131426
# 6  42.115725 -13.255491
# 7  -6.550162   9.916632
# 8  74.003832  36.285178
# 9  64.067051  28.701084
#
#  df2 after potentially dropping e and f:
#             g          h
# 0  12.818224   7.571010
# 1   5.818515  52.268135
# 2  29.005079  47.441353
# 3   0.874261 -31.797176
# 4  18.185513  32.896418
# 5   0.871919  26.131426
# 6  42.115725 -13.255491
# 7  -6.550162   9.916632
# 8  74.003832  36.285178
# 9  64.067051  28.701084

# %% [markdown]
# ## Intro to Filters (Logical indexing)
# - Filters are the selection of rows based on criteria.
# - We can select based on specific criteria.
# - These criteria can be connected together.
# - Most of the time we won't specfically assign selection critia to a list.

# %%
# At the foundation of the filter is a boolean array based on some type of condition.
print(df)
df['a'] >= 20
# Out:
#             a           b           c           d
# 0 -106.430471   90.881054   13.069950   23.149396
# 1   53.738540  -41.080465   11.879938 -211.817353
# 2  -96.347723  -23.608183  -68.466945  -93.959361
# 3   63.106793 -114.630121   47.016237   69.473786
# 4   11.724826   30.204470   -7.289911  -82.498530
# 5  240.848916  -72.941194  123.146851  190.509272
# 6 -138.235397  130.546769   18.188352   -8.109944
# 7  104.770537   49.374641  -78.345353 -159.333551
# 8  -29.548304   87.094723   37.359985   47.276173
# 9   33.257647  -92.792983   25.106776   46.964333
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# 7     True
# 8    False
# 9     True
# Name: a, dtype: bool

# %%
#notice how the logical statement is inside the dataframe specification.  This creates an intermediate boolean array.
df[df['a'] >= 20]
# Out:
#             a           b           c           d
# 1   53.738540  -41.080465   11.879938 -211.817353
# 3   63.106793 -114.630121   47.016237   69.473786
# 5  240.848916  -72.941194  123.146851  190.509272
# 7  104.770537   49.374641  -78.345353 -159.333551
# 9   33.257647  -92.792983   25.106776   46.964333

# %%
#This is an alternate method where we first set the boolean array.
included=df['a'] >= 20
df[included]
# Out:
#             a           b           c           d
# 1   53.738540  -41.080465   11.879938 -211.817353
# 3   63.106793 -114.630121   47.016237   69.473786
# 5  240.848916  -72.941194  123.146851  190.509272
# 7  104.770537   49.374641  -78.345353 -159.333551
# 9   33.257647  -92.792983   25.106776   46.964333

# %%
#We can now generate a vector based on a critera and then use this for selection
select = df['a']>=20
print (select,type(select))
print (df.loc[select,'a']) #Notice by including only one variable we are selecting rows and all columns.

select2 = (df['a']>20) & (df['c'] < 30)  #More complex criteria
print (select2)
print (df.loc[select2,['a','c']])
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# 7     True
# 8    False
# 9     True
# Name: a, dtype: bool <class 'pandas.core.series.Series'>
# 1     53.738540
# 3     63.106793
# 5    240.848916
# 7    104.770537
# 9     33.257647
# Name: a, dtype: float64
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7     True
# 8    False
# 9     True
# dtype: bool
#             a          c
# 1   53.738540  11.879938
# 7  104.770537 -78.345353
# 9   33.257647  25.106776

# %%
#Here we are creating a new variable based on the value of another variable.
df['aboveavg']=0  # We first set the default to 0.
df.loc[df['a']>=20,'aboveavg']=1 #We then change all rows where a is >=20 to 1.
print(df['aboveavg'])
# Out:
# 0    0
# 1    1
# 2    0
# 3    1
# 4    0
# 5    1
# 6    0
# 7    1
# 8    0
# 9    1
# Name: aboveavg, dtype: int64

# %% [markdown]
# ## Joining or Combining Dataframes
#
# - You can add rows vertically with the `concat` function
# - The index is not automatically reset

# %%
#This first generates 2 dataframes.
df = pd.DataFrame((20+np.random.randn(10, 4)*5),  columns=['a', 'b', 'c', 'd'] )
df2 = pd.DataFrame((20+np.random.randn(10, 4)*5),  columns=['a', 'b', 'c', 'd'] )

dfbyrow=pd.concat([df, df2])
print (dfbyrow)

df_3 = pd.concat([df, df2], ignore_index=True)
print('\n\n We have now reset the index: \n\n',df_3)
# Out:
#            a          b          c          d
# 0  12.655935  23.838636  24.131157  19.314001
# 1  13.999009  21.105106  15.257084  20.537617
# 2  23.946751  19.900735  20.846647  14.574953
# 3  21.532654  20.170814  28.999095  17.755759
# 4  26.487539  18.358480  23.899225  18.048813
# 5   6.954238  13.881763  19.858538  22.134258
# 6  29.224564  19.375586  22.575391  11.247959
# 7  18.047033  15.053147  23.265117  15.205675
# 8  20.513342  24.906694  15.176006  20.001082
# 9  27.391891  20.965096  25.961451  22.385356
# 0  21.127944  14.052390  17.735565  25.198823
# 1  16.573375   8.342991  23.728891  23.323299
# 2  11.206399  21.060595  23.968537  22.660950
# 3  22.308625  24.872349  20.606320  16.688822
# 4  15.862087  23.420373  19.995945  19.189474
# 5  20.902073  19.503763  12.778173  17.326116
# 6  16.655070  14.464856  21.076961  11.099739
# 7  31.881189  17.901275  16.598684  24.132576
# 8  13.739202   8.017390  22.414591  17.773509
# 9  28.487225  16.679654  14.259730  19.046314
#
#
#  We have now reset the index:
#
#              a          b          c          d
# 0   12.655935  23.838636  24.131157  19.314001
# 1   13.999009  21.105106  15.257084  20.537617
# 2   23.946751  19.900735  20.846647  14.574953
# 3   21.532654  20.170814  28.999095  17.755759
# 4   26.487539  18.358480  23.899225  18.048813
# 5    6.954238  13.881763  19.858538  22.134258
# 6   29.224564  19.375586  22.575391  11.247959
# 7   18.047033  15.053147  23.265117  15.205675
# 8   20.513342  24.906694  15.176006  20.001082
# 9   27.391891  20.965096  25.961451  22.385356
# 10  21.127944  14.052390  17.735565  25.198823
# 11  16.573375   8.342991  23.728891  23.323299
# 12  11.206399  21.060595  23.968537  22.660950
# 13  22.308625  24.872349  20.606320  16.688822
# 14  15.862087  23.420373  19.995945  19.189474
# 15  20.902073  19.503763  12.778173  17.326116
# 16  16.655070  14.464856  21.076961  11.099739
# 17  31.881189  17.901275  16.598684  24.132576
# 18  13.739202   8.017390  22.414591  17.773509
# 19  28.487225  16.679654  14.259730  19.046314

# %% [markdown]
# ## Inner/Outer Joins Dataframes

# %%
#Merging additional columns also uses the concat function.
#This is equivalent to an inner join in SQL.

df = pd.DataFrame((20+np.random.randn(9, 4)*5),  columns=['a', 'b', 'c', 'd'] )
df4 = pd.DataFrame((20+np.random.randn(9, 4)*5),  columns=['e', 'f', 'g', 'h'] )


dfbycolumns = pd.concat([df, df4], axis=1, join='inner')
dfbycolumns
# Out:
#            a          b          c          d          e          f  \
# 0  22.389455  26.209622  21.580616  23.717483  18.185264  15.357051
# 1  13.670404  18.093209  19.350218  22.961422  15.508825  11.165528
# 2  20.907864  14.599975  25.331534  12.972034  27.738417  12.849104
# 3  13.484374  24.550068  28.404682  19.842887  23.298499  27.115477
# 4  26.075123  20.732417  20.204948  16.566666   5.901302  16.398811
# 5  30.766033  26.394075  12.475410  17.221030  13.736043  21.765269
# 6  20.993919  20.272642  19.081062  26.929540  12.201550  23.781379
# 7  25.184130  21.385138  10.311858  28.137487  18.562828  27.222680
# 8  15.806355  20.091303  24.576442  36.603753  24.810803  18.326835
#
#            g          h
# 0  18.945212  11.125202
# 1  19.721583  15.411993
# 2  22.730806  16.998077
# 3  21.288574  20.193873
# 4  19.514082  21.966475
# 5  17.248878  20.745964
# 6  19.101472  19.397909
# 7  24.721049  21.904650
# 8  26.343492  23.250015

# %%
pd.concat([df, df4], axis=1, join='outer')
# Out:
#            a          b          c          d          e          f  \
# 0  22.389455  26.209622  21.580616  23.717483  18.185264  15.357051
# 1  13.670404  18.093209  19.350218  22.961422  15.508825  11.165528
# 2  20.907864  14.599975  25.331534  12.972034  27.738417  12.849104
# 3  13.484374  24.550068  28.404682  19.842887  23.298499  27.115477
# 4  26.075123  20.732417  20.204948  16.566666   5.901302  16.398811
# 5  30.766033  26.394075  12.475410  17.221030  13.736043  21.765269
# 6  20.993919  20.272642  19.081062  26.929540  12.201550  23.781379
# 7  25.184130  21.385138  10.311858  28.137487  18.562828  27.222680
# 8  15.806355  20.091303  24.576442  36.603753  24.810803  18.326835
#
#            g          h
# 0  18.945212  11.125202
# 1  19.721583  15.411993
# 2  22.730806  16.998077
# 3  21.288574  20.193873
# 4  19.514082  21.966475
# 5  17.248878  20.745964
# 6  19.101472  19.397909
# 7  24.721049  21.904650
# 8  26.343492  23.250015

# %%
#Here we are generating a small dataframe to be used in merging so you can see the differences in specifying inner & outer,
shortdf=df[0:5]
dfbycolumns = pd.concat([df, shortdf], axis=1, join='inner')
dfbycolumns
# Out:
#            a          b          c          d          a          b  \
# 0  22.389455  26.209622  21.580616  23.717483  22.389455  26.209622
# 1  13.670404  18.093209  19.350218  22.961422  13.670404  18.093209
# 2  20.907864  14.599975  25.331534  12.972034  20.907864  14.599975
# 3  13.484374  24.550068  28.404682  19.842887  13.484374  24.550068
# 4  26.075123  20.732417  20.204948  16.566666  26.075123  20.732417
#
#            c          d
# 0  21.580616  23.717483
# 1  19.350218  22.961422
# 2  25.331534  12.972034
# 3  28.404682  19.842887
# 4  20.204948  16.566666

# %%
#Here, the outer does the equivalent of a left outer join for this dataset.
shortdf=df[0:5]
dfbycolumns = pd.concat([df, shortdf], axis=1, join='outer')
dfbycolumns
# Out:
#            a          b          c          d          a          b  \
# 0  22.389455  26.209622  21.580616  23.717483  22.389455  26.209622
# 1  13.670404  18.093209  19.350218  22.961422  13.670404  18.093209
# 2  20.907864  14.599975  25.331534  12.972034  20.907864  14.599975
# 3  13.484374  24.550068  28.404682  19.842887  13.484374  24.550068
# 4  26.075123  20.732417  20.204948  16.566666  26.075123  20.732417
# 5  30.766033  26.394075  12.475410  17.221030        NaN        NaN
# 6  20.993919  20.272642  19.081062  26.929540        NaN        NaN
# 7  25.184130  21.385138  10.311858  28.137487        NaN        NaN
# 8  15.806355  20.091303  24.576442  36.603753        NaN        NaN
#
#            c          d
# 0  21.580616  23.717483
# 1  19.350218  22.961422
# 2  25.331534  12.972034
# 3  28.404682  19.842887
# 4  20.204948  16.566666
# 5        NaN        NaN
# 6        NaN        NaN
# 7        NaN        NaN
# 8        NaN        NaN
