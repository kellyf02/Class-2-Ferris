# %% [markdown]
# <a href="https://colab.research.google.com/github/kellyf02/Class-2-Ferris/blob/main/Week_4_Ferris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise: GroupBy
# Alcohol Consumption Exercise

# %% [markdown]
# ### Introduction:
#
# Thanks to: https://github.com/justmarkham for the dataset and materials.
#
# Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# [link text](https://)### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv), and assign it to a variable called drinks.

# %%
drinks = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv')
drinks.head(20)
# Out:
#               country  beer_servings  spirit_servings  wine_servings  \
# 0         Afghanistan              0                0              0
# 1             Albania             89              132             54
# 2             Algeria             25                0             14
# 3             Andorra            245              138            312
# 4              Angola            217               57             45
# 5   Antigua & Barbuda            102              128             45
# 6           Argentina            193               25            221
# 7             Armenia             21              179             11
# 8           Australia            261               72            212
# 9             Austria            279               75            191
# 10         Azerbaijan             21               46              5
# 11            Bahamas            122              176             51
# 12            Bahrain             42               63              7
# 13         Bangladesh              0                0              0
# 14           Barbados            143              173             36
# 15            Belarus            142              373             42
# 16            Belgium            295               84            212
# 17             Belize            263              114              8
# 18              Benin             34                4             13
# 19             Bhutan             23                0              0
#
#     total_litres_of_pure_alcohol continent
# 0                            0.0        AS
# 1                            4.9        EU
# 2                            0.7        AF
# 3                           12.4        EU
# 4                            5.9        AF
# 5                            4.9       NaN
# 6                            8.3        SA
# 7                            3.8        EU
# 8                           10.4        OC
# 9                            9.7        EU
# 10                           1.3        EU
# 11                           6.3       NaN
# 12                           2.0        AS
# 13                           0.0        AS
# 14                           6.3       NaN
# 15                          14.4        EU
# 16                          10.5        EU
# 17                           6.8       NaN
# 18                           1.1        AF
# 19                           0.4        AS

# %% [markdown]
# ### What is the number of observations in the dataset?

# %%
drinks.info() # for rows and columns
drinks.shape[0] # for rows
drinks.shape[1] # for columns
drinks.info()

drinks.shape[0]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     170 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     170 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB
# 193

# %% [markdown]
# ### Show me the names of all columns, and how the dataset is indexed.

# %%
print('The column names are:',drinks.columns)
print('\n\nThe index:',drinks.index)
# Out:
# The column names are: Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')
#
#
# The index: RangeIndex(start=0, stop=193, step=1)

# %% [markdown]
# ## How many continents are there?

# %%
drinks.continent.unique()
drinks.continent.nunique()
# Out:
# 5

# %%
drinks.continent.value_counts().head()
# Out:
# continent
# AF    53
# EU    45
# AS    44
# OC    16
# SA    12
# Name: count, dtype: int64

# %% [markdown]
# ### How much beer does the world drink on average?

# %%
drinks['beer_servings'].mean()
drinks.beer_servings.mean()
# Out:
# 106.16062176165804

# %% [markdown]
# ### Class Exercise: How much spirit does the world drink in total? Hint: SUM

# %%
## Enter your answer here:
drinks.spirit_servings.sum()
# Out:
# 15632

# %% [markdown]
# ### Which country drinks the highest servings of wine?
#
# Steps: Find the index location where wine_serving is highest. Next, locate the name of the country attached to this high wine consumption.

# %%
print('highest servings of wine is located at row:',drinks['wine_servings'].idxmax())

print('\nThe country that drinks the highest amount of wine is:',drinks['country'][drinks['wine_servings'].idxmax()])

print('\nThe other features of France:\n',drinks.loc[drinks['wine_servings'].idxmax()])
# Out:
# highest servings of wine is located at row: 61
#
# The country that drinks the highest amount of wine is: France
#
# The other features of France:
#  country                         France
# beer_servings                      127
# spirit_servings                    151
# wine_servings                      370
# total_litres_of_pure_alcohol      11.8
# continent                           EU
# Name: 61, dtype: object

# %%
drinks['wine_servings'].idxmax()

drinks['country'].loc[drinks['wine_servings'].idxmax()]

drinks.loc[drinks['wine_serivings']]
# Out:
# 'France'

# %%
## Alternatively, sort drinks by highest wine servings
drinks.sort_values(by='wine_servings',ascending=False).head()
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 61        France            127              151            370
# 136     Portugal            194               67            339
# 3        Andorra            245              138            312
# 166  Switzerland            185              100            280
# 48       Denmark            224               81            278
#
#      total_litres_of_pure_alcohol continent
# 61                           11.8        EU
# 136                          11.0        EU
# 3                            12.4        EU
# 166                          10.2        EU
# 48                           10.4        EU

# %% [markdown]
# ## Class Exercise: How much servings of wine is had by the country that drinks the most servings of spirit? Which country is it?

# %%
country_with_most_spirit = drinks.loc[drinks['spirit_servings'].idxmax(), 'country']
country_with_most_spirit
# Out:
# 'Grenada'

# %%
wine_servings_for_country = drinks.loc[drinks['country'] == country_with_most_spirit, 'wine_servings'].values[0]
wine_servings_for_country
# Out:
# 28

# %%
print(f"{country_with_most_spirit} drinks the most spirit and has {wine_servings_for_country} servings of wine.")
# Out:
# Grenada drinks the most spirit and has 28 servings of wine.

# %%
country_with_most_spirit = drinks.loc[drinks['spirit_servings'].idxmax(), 'country']
wine_servings_for_country = drinks.loc[drinks['country'] == country_with_most_spirit, 'wine_servings'].values[0]
print(f"{country_with_most_spirit} drinks the most spirit and has {wine_servings_for_country} servings of wine.")
# Out:
# Grenada drinks the most spirit and has 28 servings of wine.

# %% [markdown]
# ## We will now start grouping by a category to answer more complicated questions.
#
# #### Which continent drinks the most beer on average? To answer this, we will GROUPBY continent and then find the average.

# %%
# drinks.beer_servings.mean()

drinks.groupby('continent').beer_servings.mean()
# Out:
# continent
# AF     61.471698
# AS     37.045455
# EU    193.777778
# OC     89.687500
# SA    175.083333
# Name: beer_servings, dtype: float64

# %%
print('The continent that drinks the most beer:',drinks.groupby('continent').beer_servings.mean().idxmax())

drinks.groupby('continent').beer_servings.mean().sort_values(ascending=False)
# Out:
# The continent that drinks the most beer: EU
# continent
# EU    193.777778
# SA    175.083333
# OC     89.687500
# AF     61.471698
# AS     37.045455
# Name: beer_servings, dtype: float64

# %% [markdown]
# ## Class Exercise: Print the summary statistics for wine consumption for each continent.

# %%
## Enter your answer here
drinks.groupby('continent').wine_servings.describe()
# Out:
#            count        mean        std  min   25%    50%     75%    max
# continent
# AF          53.0   16.264151  38.846419  0.0   1.0    2.0   13.00  233.0
# AS          44.0    9.068182  21.667034  0.0   0.0    1.0    8.00  123.0
# EU          45.0  142.222222  97.421738  0.0  59.0  128.0  195.00  370.0
# OC          16.0   35.625000  64.555790  0.0   1.0    8.5   23.25  212.0
# SA          12.0   62.416667  88.620189  1.0   3.0   12.0   98.50  221.0

# %% [markdown]
# ### Print the mean alcohol consumption per continent for every type of alcohol

# %%
drinks.groupby('continent').wine_servings.mean()
# Out:
# continent
# AF     16.264151
# AS      9.068182
# EU    142.222222
# OC     35.625000
# SA     62.416667
# Name: wine_servings, dtype: float64

# %% [markdown]
# ### Class Exercise: Print the median alcohol consumption per continent for
#
# 1.   List item
# 2.   List item
#
# every column

# %%
## Enter your answer here
drinks.groupby('continent').agg({'beer_servings': 'median', 'spirit_servings': 'median', 'wine_servings': 'median', 'total_litres_of_pure_alcohol': 'median'})
# OR
drinks.groupby('continent')[['beer_servings', 'spirit_servings', 'wine_servings', 'total_litres_of_pure_alcohol']].median()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF                  32.0              3.0            2.0
# AS                  17.5             16.0            1.0
# EU                 219.0            122.0          128.0
# OC                  52.5             37.0            8.5
# SA                 162.5            108.5           12.0
#
#            total_litres_of_pure_alcohol
# continent
# AF                                 2.30
# AS                                 1.20
# EU                                10.00
# OC                                 1.75
# SA                                 6.85

# %% [markdown]
# ### Print the mean, min and max values for spirit consumption.

# %%
drinks.groupby('continent').spirit_servings.agg(['mean', 'min', 'max'])
# Out:
#                  mean  min  max
# continent
# AF          16.339623    0  152
# AS          60.840909    0  326
# EU         132.555556    0  373
# OC          58.437500    0  254
# SA         114.750000   25  302

# %% [markdown]
# ##Reset Index to Continent, and set it back to how it was previously

# %%
# Set the index back to original index
drinks1 = drinks.set_index('continent')
drinks1.head()
# reset index of drinks1

drinks1 = drinks.set_index('continent')
drinks1.head()
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# continent
# AS         Afghanistan              0                0              0
# EU             Albania             89              132             54
# AF             Algeria             25                0             14
# EU             Andorra            245              138            312
# AF              Angola            217               57             45
#
#            total_litres_of_pure_alcohol
# continent
# AS                                  0.0
# EU                                  4.9
# AF                                  0.7
# EU                                 12.4
# AF                                  5.9
